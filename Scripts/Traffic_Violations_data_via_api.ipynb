# %%
import pandas as pd
import numpy as np
import requests
import json

import pymysql
from sqlalchemy import create_engine
import sqlite3

# %%
url = "https://data.ny.gov/resource/q4hy-kbtf.json?$limit=500000"
headers = {
"Content-Type" : "application/json",
}


response_API = requests.get(url,headers=headers)
print(response_API.status_code)
# Out:
# 200

# %%
data = response_API.text
data = json.loads(data)
data
# Out:
# [{'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'WEDNESDAY',
#   'age_at_violation': '34',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '28',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1163AT',
#   'violation_description': 'IMPROPER TURN',
#   'violation_year': '2019',
#   'violation_month': '6',
#   'violation_dow': 'SATURDAY',
#   'age_at_violation': '57',
#   'gender': 'M',
#   'state_of_license': 'NEW JERSEY',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'QUEENS SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'WEDNESDAY',
#   'age_at_violation': '33',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1163AT',
#   'violation_description': 'IMPROPER TURN',
#   'violation_year': '2019',
#   'violation_month': '3',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '36',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '42',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1172A',
#   'violation_description': 'FLD TO STOP AT STOP SIGN',
#   'violation_year': '2019',
#   'violation_month': '6',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '32',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225D',
#   'violation_description': 'OPER MV WHILE USING PORTABLE ELEC DEV',
#   'violation_year': '2019',
#   'violation_month': '5',
#   'violation_dow': 'SATURDAY',
#   'age_at_violation': '38',
#   'gender': 'F',
#   'state_of_license': 'NEW JERSEY',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1229C3A',
#   'violation_description': 'NO LAP/SHOULDER HARNESS OR DJ VIO',
#   'violation_year': '2019',
#   'violation_month': '5',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '73',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1172A',
#   'violation_description': 'FLD TO STOP AT STOP SIGN',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '25',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '37512A2',
#   'violation_description': 'SIDEWINGS/SIDEWINDOWS/NON/TRANSPARENT',
#   'violation_year': '2019',
#   'violation_month': '8',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '32',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1172A',
#   'violation_description': 'FLD TO STOP AT STOP SIGN',
#   'violation_year': '2019',
#   'violation_month': '4',
#   'violation_dow': 'WEDNESDAY',
#   'age_at_violation': '34',
#   'gender': 'M',
#   'state_of_license': 'PENNSYLVANIA',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '403A1',
#   'violation_description': 'FLD YIELD PEDEST NYC',
#   'violation_year': '2019',
#   'violation_month': '5',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '58',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225D',
#   'violation_description': 'OPER MV WHILE USING PORTABLE ELEC DEV',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '36',
#   'gender': 'M',
#   'state_of_license': 'NEW JERSEY',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '2',
#   'violation_dow': 'WEDNESDAY',
#   'age_at_violation': '45',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225D1A',
#   'violation_description': 'MOTOR CARRIER ALLOW/REQUIRE DRIVER TO USE PORTABLE ELECTR DEVICE WHILE OPER CMV',
#   'violation_year': '2019',
#   'violation_month': '2',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '58',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '3',
#   'violation_dow': 'WEDNESDAY',
#   'age_at_violation': '68',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '5091G',
#   'violation_description': 'UNLICENSED GT 60DAYS',
#   'violation_year': '2019',
#   'violation_month': '4',
#   'violation_dow': 'SATURDAY',
#   'age_at_violation': '84',
#   'gender': 'M',
#   'state_of_license': 'UNKNOWN',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225D1A',
#   'violation_description': 'MOTOR CARRIER ALLOW/REQUIRE DRIVER TO USE PORTABLE ELECTR DEVICE WHILE OPER CMV',
#   'violation_year': '2019',
#   'violation_month': '4',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '34',
#   'gender': 'M',
#   'state_of_license': 'NEW JERSEY',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225D1A',
#   'violation_description': 'MOTOR CARRIER ALLOW/REQUIRE DRIVER TO USE PORTABLE ELECTR DEVICE WHILE OPER CMV',
#   'violation_year': '2019',
#   'violation_month': '5',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '44',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225D1A',
#   'violation_description': 'MOTOR CARRIER ALLOW/REQUIRE DRIVER TO USE PORTABLE ELECTR DEVICE WHILE OPER CMV',
#   'violation_year': '2019',
#   'violation_month': '6',
#   'violation_dow': 'WEDNESDAY',
#   'age_at_violation': '23',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225D1A',
#   'violation_description': 'MOTOR CARRIER ALLOW/REQUIRE DRIVER TO USE PORTABLE ELECTR DEVICE WHILE OPER CMV',
#   'violation_year': '2019',
#   'violation_month': '6',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '37',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '4',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '26',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '7',
#   'violation_dow': 'WEDNESDAY',
#   'age_at_violation': '28',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '5',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '36',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '5092',
#   'violation_description': 'OPERATING OUT OF CLASS',
#   'violation_year': '2019',
#   'violation_month': '6',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '36',
#   'gender': 'M',
#   'state_of_license': 'UNKNOWN',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1127AB',
#   'violation_description': 'DROVE WRONG DIRECTION BICYCLE',
#   'violation_year': '2019',
#   'violation_month': '7',
#   'violation_dow': 'WEDNESDAY',
#   'age_at_violation': '19',
#   'gender': 'M',
#   'state_of_license': 'UNKNOWN',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '3',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '21',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '3',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '21',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1172A',
#   'violation_description': 'FLD TO STOP AT STOP SIGN',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '44',
#   'gender': 'M',
#   'state_of_license': 'PENNSYLVANIA',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225C2A',
#   'violation_description': 'OPERATING MV MOBILE PHONE',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '36',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'QUEENS NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225C2A',
#   'violation_description': 'OPERATING MV MOBILE PHONE',
#   'violation_year': '2019',
#   'violation_month': '3',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '33',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225D',
#   'violation_description': 'OPER MV WHILE USING PORTABLE ELEC DEV',
#   'violation_year': '2019',
#   'violation_month': '7',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '26',
#   'gender': 'M',
#   'state_of_license': 'UNKNOWN',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1174A',
#   'violation_description': 'FLD TO STOP SCHOOL BUS',
#   'violation_year': '2019',
#   'violation_month': '3',
#   'violation_dow': 'WEDNESDAY',
#   'age_at_violation': '33',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '3816',
#   'violation_description': 'UNAPPROVED/NO PROTECTIVE HELMET MCY',
#   'violation_year': '2019',
#   'violation_month': '8',
#   'violation_dow': 'SATURDAY',
#   'age_at_violation': '27',
#   'gender': 'M',
#   'state_of_license': 'TENNESSEE',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'SATURDAY',
#   'age_at_violation': '24',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '3',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '47',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '5091G',
#   'violation_description': 'UNLICENSED GT 60DAYS',
#   'violation_year': '2019',
#   'violation_month': '2',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '40',
#   'gender': 'M',
#   'state_of_license': 'UNKNOWN',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1163D',
#   'violation_description': 'IMPROPER SIGNAL',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '32',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BRONX TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '10',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '31',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BRONX TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '2',
#   'violation_dow': 'SATURDAY',
#   'age_at_violation': '37',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BRONX TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '3752A1I',
#   'violation_description': 'INSUFF HEADLIGHTS',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '28',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BRONX TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225D',
#   'violation_description': 'OPER MV WHILE USING PORTABLE ELEC DEV',
#   'violation_year': '2019',
#   'violation_month': '4',
#   'violation_dow': 'WEDNESDAY',
#   'age_at_violation': '32',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BRONX TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '6',
#   'violation_dow': 'WEDNESDAY',
#   'age_at_violation': '60',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2019',
#   'violation_month': '10',
#   'violation_dow': 'SATURDAY',
#   'age_at_violation': '37',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1163AT',
#   'violation_description': 'IMPROPER TURN',
#   'violation_year': '2019',
#   'violation_month': '4',
#   'violation_dow': 'WEDNESDAY',
#   'age_at_violation': '32',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1163AT',
#   'violation_description': 'IMPROPER TURN',
#   'violation_year': '2019',
#   'violation_month': '8',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '43',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '5',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '57',
#   'gender': 'M',
#   'state_of_license': 'PENNSYLVANIA',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1172A',
#   'violation_description': 'FLD TO STOP AT STOP SIGN',
#   'violation_year': '2019',
#   'violation_month': '4',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '26',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '5091G',
#   'violation_description': 'UNLICENSED GT 60DAYS',
#   'violation_year': '2019',
#   'violation_month': '12',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '27',
#   'gender': 'M',
#   'state_of_license': 'UNKNOWN',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'QUEENS NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '8',
#   'violation_dow': 'WEDNESDAY',
#   'age_at_violation': '40',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1160A',
#   'violation_description': 'IMPROPER RIGHT TURN',
#   'violation_year': '2019',
#   'violation_month': '6',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '66',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '7',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '53',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1160B',
#   'violation_description': 'IMPROPER LEFT TURN ON TWO-WAY RDWY',
#   'violation_year': '2019',
#   'violation_month': '6',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '50',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1160C',
#   'violation_description': 'IMPROPER LEFT TURN ON ONE-WAY RDWY',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '25',
#   'gender': 'M',
#   'state_of_license': 'CONNECTICUT',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '12',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '37',
#   'gender': 'M',
#   'state_of_license': 'NEW JERSEY',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1160A',
#   'violation_description': 'IMPROPER RIGHT TURN',
#   'violation_year': '2019',
#   'violation_month': '7',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '60',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1163D',
#   'violation_description': 'IMPROPER SIGNAL',
#   'violation_year': '2019',
#   'violation_month': '11',
#   'violation_dow': 'SATURDAY',
#   'age_at_violation': '21',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225C2A',
#   'violation_description': 'OPERATING MV MOBILE PHONE',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '84',
#   'gender': 'M',
#   'state_of_license': 'NEW JERSEY',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1122A',
#   'violation_description': 'PASSED VEHICLE ON RIGHT',
#   'violation_year': '2019',
#   'violation_month': '2',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '22',
#   'gender': 'M',
#   'state_of_license': 'VIRGINIA',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1234A',
#   'violation_description': 'FAILURE TO KEEP RIGHT-BICYCLE',
#   'violation_year': '2019',
#   'violation_month': '7',
#   'violation_dow': 'WEDNESDAY',
#   'age_at_violation': '57',
#   'gender': 'M',
#   'state_of_license': 'UNKNOWN',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '403A1',
#   'violation_description': 'FLD YIELD PEDEST NYC',
#   'violation_year': '2019',
#   'violation_month': '3',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '28',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '37512A2',
#   'violation_description': 'SIDEWINGS/SIDEWINDOWS/NON/TRANSPARENT',
#   'violation_year': '2019',
#   'violation_month': '11',
#   'violation_dow': 'WEDNESDAY',
#   'age_at_violation': '25',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D3',
#   'violation_description': 'FLD TO STOP ON A STEADY RED ARROW',
#   'violation_year': '2019',
#   'violation_month': '4',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '38',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '37512A2',
#   'violation_description': 'SIDEWINGS/SIDEWINDOWS/NON/TRANSPARENT',
#   'violation_year': '2019',
#   'violation_month': '6',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '41',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '6',
#   'violation_dow': 'WEDNESDAY',
#   'age_at_violation': '42',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '10',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '20',
#   'gender': 'M',
#   'state_of_license': 'UNKNOWN',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1229C3A',
#   'violation_description': 'NO LAP/SHOULDER HARNESS OR DJ VIO',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'SATURDAY',
#   'age_at_violation': '19',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1229C3U',
#   'violation_description': 'NO BELT OPER TAXI',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '51',
#   'gender': 'M',
#   'state_of_license': 'UNKNOWN',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '4114',
#   'violation_description': 'PERMITTING IMPROPER USE/ PLATES MCY',
#   'violation_year': '2019',
#   'violation_month': '4',
#   'violation_dow': 'WEDNESDAY',
#   'age_at_violation': '45',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1C',
#   'violation_description': 'NYC BIKE/SKATE RDLGT',
#   'violation_year': '2019',
#   'violation_month': '4',
#   'violation_dow': 'WEDNESDAY',
#   'age_at_violation': '44',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2019',
#   'violation_month': '11',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '59',
#   'gender': 'M',
#   'state_of_license': 'CALIFORNIA',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1229C3',
#   'violation_description': 'NO SEAT BELT ADULT',
#   'violation_year': '2019',
#   'violation_month': '12',
#   'violation_dow': 'SATURDAY',
#   'age_at_violation': '31',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1128A',
#   'violation_description': 'MOVED FROM LANE UNSAFELY/WEAVING',
#   'violation_year': '2019',
#   'violation_month': '7',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '41',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '7',
#   'violation_dow': 'SATURDAY',
#   'age_at_violation': '23',
#   'gender': 'F',
#   'state_of_license': 'UNKNOWN',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '4',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '49',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1163D',
#   'violation_description': 'IMPROPER SIGNAL',
#   'violation_year': '2019',
#   'violation_month': '10',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '44',
#   'gender': 'M',
#   'state_of_license': 'GEORGIA',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '3191U',
#   'violation_description': 'OPERATING W/O INSURANCE',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'SATURDAY',
#   'age_at_violation': '51',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '37522',
#   'violation_description': 'VISIBILITY DISTORTED BROKEN/DISCOLORED GLASS',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'SATURDAY',
#   'age_at_violation': '51',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225C2A',
#   'violation_description': 'OPERATING MV MOBILE PHONE',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'SATURDAY',
#   'age_at_violation': '51',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '6',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '51',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'RICHMOND TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225D',
#   'violation_description': 'OPER MV WHILE USING PORTABLE ELEC DEV',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '55',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '412M',
#   'violation_description': 'IMP USE BUS LANE NYC',
#   'violation_year': '2019',
#   'violation_month': '3',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '38',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '4',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '24',
#   'gender': 'M',
#   'state_of_license': 'FLORIDA',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '6',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '21',
#   'gender': 'M',
#   'state_of_license': 'PENNSYLVANIA',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '7',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '29',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225D',
#   'violation_description': 'OPER MV WHILE USING PORTABLE ELEC DEV',
#   'violation_year': '2019',
#   'violation_month': '7',
#   'violation_dow': 'WEDNESDAY',
#   'age_at_violation': '20',
#   'gender': 'M',
#   'state_of_license': 'NEW JERSEY',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '7',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '29',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '4',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '59',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225C2A',
#   'violation_description': 'OPERATING MV MOBILE PHONE',
#   'violation_year': '2019',
#   'violation_month': '4',
#   'violation_dow': 'WEDNESDAY',
#   'age_at_violation': '56',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'QUEENS NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '11',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '47',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'QUEENS NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '37540B',
#   'violation_description': 'INADEQUATE OR NO STOP LAMPS',
#   'violation_year': '2019',
#   'violation_month': '6',
#   'violation_dow': 'SATURDAY',
#   'age_at_violation': '33',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BRONX TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1229C3A',
#   'violation_description': 'NO LAP/SHOULDER HARNESS OR DJ VIO',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '31',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'QUEENS NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1163D',
#   'violation_description': 'IMPROPER SIGNAL',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'WEDNESDAY',
#   'age_at_violation': '27',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'QUEENS NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1229C3A',
#   'violation_description': 'NO LAP/SHOULDER HARNESS OR DJ VIO',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '30',
#   'gender': 'F',
#   'state_of_license': 'UNKNOWN',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'QUEENS NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '5091G',
#   'violation_description': 'UNLICENSED GT 60DAYS',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '30',
#   'gender': 'F',
#   'state_of_license': 'UNKNOWN',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'QUEENS NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '37540B',
#   'violation_description': 'INADEQUATE OR NO STOP LAMPS',
#   'violation_year': '2019',
#   'violation_month': '10',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '32',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'MTA POLICE DEPT HDQRS',
#   'court': 'QUEENS SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '38511',
#   'violation_description': 'OVERLOAD ON SOLID RUBBER TIRES',
#   'violation_year': '2019',
#   'violation_month': '10',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '29',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'MTA POLICE DEPT HDQRS',
#   'court': 'QUEENS SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '5092',
#   'violation_description': 'OPERATING OUT OF CLASS',
#   'violation_year': '2019',
#   'violation_month': '2',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '67',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '10127B',
#   'violation_description': 'NO LETTERNG-COMM VEH',
#   'violation_year': '2019',
#   'violation_month': '5',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '75',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '4011A',
#   'violation_description': 'UNREGISTERED MOTOR VEHICLE',
#   'violation_year': '2019',
#   'violation_month': '2',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '46',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'PORT AUTHORITY OF NY & NJ',
#   'court': 'RICHMOND TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '4011A',
#   'violation_description': 'UNREGISTERED MOTOR VEHICLE',
#   'violation_year': '2019',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '22',
#   'gender': 'M',
#   'state_of_license': 'CALIFORNIA',
#   'police_agency': 'PORT AUTHORITY OF NY & NJ',
#   'court': 'RICHMOND TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '3191U',
#   'violation_description': 'OPERATING W/O INSURANCE',
#   'violation_year': '2019',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '22',
#   'gender': 'M',
#   'state_of_license': 'CALIFORNIA',
#   'police_agency': 'PORT AUTHORITY OF NY & NJ',
#   'court': 'RICHMOND TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '5091',
#   'violation_description': 'UNLICENSED OPERATOR',
#   'violation_year': '2019',
#   'violation_month': '2',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '27',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'PORT AUTHORITY OF NY & NJ',
#   'court': 'RICHMOND TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '10212',
#   'violation_description': 'OVERSIZ/WT VEHS-TBTA',
#   'violation_year': '2019',
#   'violation_month': '11',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '27',
#   'gender': 'M',
#   'state_of_license': 'NEW JERSEY',
#   'police_agency': 'TRIBOROUGH BRIDGE TUNNEL AUTH',
#   'court': 'QUEENS SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '10212',
#   'violation_description': 'OVERSIZ/WT VEHS-TBTA',
#   'violation_year': '2019',
#   'violation_month': '8',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '37',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'TRIBOROUGH BRIDGE TUNNEL AUTH',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '10212',
#   'violation_description': 'OVERSIZ/WT VEHS-TBTA',
#   'violation_year': '2019',
#   'violation_month': '5',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '63',
#   'gender': 'M',
#   'state_of_license': 'CALIFORNIA',
#   'police_agency': 'TRIBOROUGH BRIDGE TUNNEL AUTH',
#   'court': 'BROOKLYN NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2019',
#   'violation_month': '11',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '33',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'PORT AUTHORITY OF NY & NJ',
#   'court': 'QUEENS SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1180D12',
#   'violation_description': 'SPEED IN ZONE 11-30',
#   'violation_year': '2019',
#   'violation_month': '11',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '40',
#   'gender': 'M',
#   'state_of_license': 'NEW JERSEY',
#   'police_agency': 'PORT AUTHORITY OF NY & NJ',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1180D12',
#   'violation_description': 'SPEED IN ZONE 11-30',
#   'violation_year': '2019',
#   'violation_month': '11',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '48',
#   'gender': 'M',
#   'state_of_license': 'NEW JERSEY',
#   'police_agency': 'PORT AUTHORITY OF NY & NJ',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '11',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '63',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'PORT AUTHORITY OF NY & NJ',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1180A',
#   'violation_description': 'SPEED NOT REASONABLE AND PRUDENT',
#   'violation_year': '2019',
#   'violation_month': '12',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '21',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'PORT AUTHORITY OF NY & NJ',
#   'court': 'QUEENS SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '5091G',
#   'violation_description': 'UNLICENSED GT 60DAYS',
#   'violation_year': '2019',
#   'violation_month': '4',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '34',
#   'gender': 'M',
#   'state_of_license': 'CONNECTICUT',
#   'police_agency': 'PORT AUTHORITY OF NY & NJ',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '4',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '34',
#   'gender': 'M',
#   'state_of_license': 'CONNECTICUT',
#   'police_agency': 'PORT AUTHORITY OF NY & NJ',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '6001A',
#   'violation_description': 'LEAVING/SCENE PROPERTY DAMAGE ACCIDENT',
#   'violation_year': '2019',
#   'violation_month': '2',
#   'violation_dow': 'FRIDAY',
#   'gender': 'M',
#   'state_of_license': 'FLORIDA',
#   'police_agency': 'PORT AUTHORITY OF NY & NJ',
#   'court': 'BROOKLYN NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1144A',
#   'violation_description': 'FLD TO YLD RT-OF-WAY TO EMERGENCY VEHICLE',
#   'violation_year': '2019',
#   'violation_month': '2',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '22',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'PORT AUTHORITY OF NY & NJ',
#   'court': 'MANHATTAN NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1102',
#   'violation_description': 'FAILED TO COMPLY W/LAWFUL ORDER',
#   'violation_year': '2019',
#   'violation_month': '2',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '22',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'PORT AUTHORITY OF NY & NJ',
#   'court': 'MANHATTAN NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1163D',
#   'violation_description': 'IMPROPER SIGNAL',
#   'violation_year': '2019',
#   'violation_month': '8',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '32',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '12',
#   'violation_dow': 'SATURDAY',
#   'age_at_violation': '48',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '414A2',
#   'violation_description': 'NO CMV ON PKWAY NYC',
#   'violation_year': '2019',
#   'violation_month': '7',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '22',
#   'gender': 'M',
#   'state_of_license': 'PENNSYLVANIA',
#   'police_agency': 'TRIBOROUGH BRIDGE TUNNEL AUTH',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '35',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'TRIBOROUGH BRIDGE TUNNEL AUTH',
#   'court': 'QUEENS SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '4021',
#   'violation_description': 'PLATE MISSING/INSECURE/DIRTY',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '44',
#   'gender': 'M',
#   'state_of_license': 'NEW JERSEY',
#   'police_agency': 'TRIBOROUGH BRIDGE TUNNEL AUTH',
#   'court': 'QUEENS NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '4021',
#   'violation_description': 'PLATE MISSING/INSECURE/DIRTY',
#   'violation_year': '2019',
#   'violation_month': '2',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '58',
#   'gender': 'M',
#   'state_of_license': 'NEW JERSEY',
#   'police_agency': 'TRIBOROUGH BRIDGE TUNNEL AUTH',
#   'court': 'QUEENS NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '9',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '39',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'PORT AUTHORITY OF NY & NJ',
#   'court': 'QUEENS SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '4014',
#   'violation_description': 'FAILURE TO PRODUCE LICENSE OR REGISTRATION DOCUMENTS',
#   'violation_year': '2019',
#   'violation_month': '10',
#   'violation_dow': 'FRIDAY',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'PORT AUTHORITY OF NY & NJ',
#   'court': 'RICHMOND TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '37540B',
#   'violation_description': 'INADEQUATE OR NO STOP LAMPS',
#   'violation_year': '2019',
#   'violation_month': '9',
#   'violation_dow': 'TUESDAY',
#   'gender': 'M',
#   'state_of_license': 'NEW JERSEY',
#   'police_agency': 'PORT AUTHORITY OF NY & NJ',
#   'court': 'RICHMOND TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '3193',
#   'violation_description': 'FAILED TO PRODUCE INSURANCE CARD',
#   'violation_year': '2019',
#   'violation_month': '10',
#   'violation_dow': 'WEDNESDAY',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'PORT AUTHORITY OF NY & NJ',
#   'court': 'RICHMOND TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '4021',
#   'violation_description': 'PLATE MISSING/INSECURE/DIRTY',
#   'violation_year': '2019',
#   'violation_month': '9',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '36',
#   'gender': 'M',
#   'state_of_license': 'MARYLAND',
#   'police_agency': 'PORT AUTHORITY OF NY & NJ',
#   'court': 'RICHMOND TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '4021',
#   'violation_description': 'PLATE MISSING/INSECURE/DIRTY',
#   'violation_year': '2019',
#   'violation_month': '10',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '20',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'PORT AUTHORITY OF NY & NJ',
#   'court': 'RICHMOND TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '4021',
#   'violation_description': 'PLATE MISSING/INSECURE/DIRTY',
#   'violation_year': '2019',
#   'violation_month': '10',
#   'violation_dow': 'WEDNESDAY',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'PORT AUTHORITY OF NY & NJ',
#   'court': 'RICHMOND TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '37540B',
#   'violation_description': 'INADEQUATE OR NO STOP LAMPS',
#   'violation_year': '2019',
#   'violation_month': '10',
#   'violation_dow': 'MONDAY',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'PORT AUTHORITY OF NY & NJ',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '10',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '61',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'PORT AUTHORITY OF NY & NJ',
#   'court': 'RICHMOND TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1172A',
#   'violation_description': 'FLD TO STOP AT STOP SIGN',
#   'violation_year': '2019',
#   'violation_month': '6',
#   'violation_dow': 'SATURDAY',
#   'age_at_violation': '35',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'SEAGATE NY HARBOR POLICE',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1127A',
#   'violation_description': 'DRIVING/WRONG DIRECTION ON ONE-WAY STREET',
#   'violation_year': '2019',
#   'violation_month': '6',
#   'violation_dow': 'WEDNESDAY',
#   'age_at_violation': '48',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'SEAGATE NY HARBOR POLICE',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '412A3',
#   'violation_description': 'FLD PRESENT DOC -NYC',
#   'violation_year': '2019',
#   'violation_month': '7',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '27',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'SEAGATE NY HARBOR POLICE',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1127A',
#   'violation_description': 'DRIVING/WRONG DIRECTION ON ONE-WAY STREET',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '49',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'SEAGATE NY HARBOR POLICE',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1128A',
#   'violation_description': 'MOVED FROM LANE UNSAFELY/WEAVING',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '60',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
# ...
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '36',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'QUEENS NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1127AB',
#   'violation_description': 'DROVE WRONG DIRECTION BICYCLE',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '60',
#   'gender': 'F',
#   'state_of_license': 'UNKNOWN',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1160A',
#   'violation_description': 'IMPROPER RIGHT TURN',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '55',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'QUEENS NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225D',
#   'violation_description': 'OPER MV WHILE USING PORTABLE ELEC DEV',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '58',
#   'gender': 'M',
#   'state_of_license': 'MARYLAND',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1180D12',
#   'violation_description': 'SPEED IN ZONE 11-30',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '21',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'QUEENS NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '52',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1180D12',
#   'violation_description': 'SPEED IN ZONE 11-30',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '43',
#   'gender': 'M',
#   'state_of_license': 'PENNSYLVANIA',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '73',
#   'gender': 'M',
#   'state_of_license': 'SOUTH CAROLINA',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1C',
#   'violation_description': 'NYC BIKE/SKATE RDLGT',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '44',
#   'gender': 'M',
#   'state_of_license': 'NEW JERSEY',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1180D12',
#   'violation_description': 'SPEED IN ZONE 11-30',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '51',
#   'gender': 'M',
#   'state_of_license': 'PENNSYLVANIA',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'RICHMOND TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '45',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1180D12',
#   'violation_description': 'SPEED IN ZONE 11-30',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '29',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '4011AG',
#   'violation_description': 'UNREG VEH > 60 DAYS',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '73',
#   'gender': 'M',
#   'state_of_license': 'SOUTH CAROLINA',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '52',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BRONX TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1172A',
#   'violation_description': 'FLD TO STOP AT STOP SIGN',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '46',
#   'gender': 'M',
#   'state_of_license': 'WASHINGTON',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'QUEENS SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1236B',
#   'violation_description': 'NO BELL OR SIGNAL DEVICE ON BICYCLE',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '27',
#   'gender': 'M',
#   'state_of_license': 'UNKNOWN',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1180D12',
#   'violation_description': 'SPEED IN ZONE 11-30',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '21',
#   'gender': 'F',
#   'state_of_license': 'MASSACHUSETTS',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BRONX TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '54',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'QUEENS SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '5092',
#   'violation_description': 'OPERATING OUT OF CLASS',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '32',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '412M',
#   'violation_description': 'IMP USE BUS LANE NYC',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '32',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '403A1',
#   'violation_description': 'FLD YIELD PEDEST NYC',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '55',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'QUEENS NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225D',
#   'violation_description': 'OPER MV WHILE USING PORTABLE ELEC DEV',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '24',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'QUEENS SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '69',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225D',
#   'violation_description': 'OPER MV WHILE USING PORTABLE ELEC DEV',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '46',
#   'gender': 'M',
#   'state_of_license': 'WASHINGTON',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'QUEENS SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1180D12',
#   'violation_description': 'SPEED IN ZONE 11-30',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '33',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'RICHMOND TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '37512A2',
#   'violation_description': 'SIDEWINGS/SIDEWINDOWS/NON/TRANSPARENT',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '57',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1163AT',
#   'violation_description': 'IMPROPER TURN',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '55',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225C2A',
#   'violation_description': 'OPERATING MV MOBILE PHONE',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '39',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BRONX TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '44',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1229C3A',
#   'violation_description': 'NO LAP/SHOULDER HARNESS OR DJ VIO',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '42',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BRONX TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1236E',
#   'violation_description': 'NO/IMPROPER REFLECTOR-BICYCLE',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '27',
#   'gender': 'M',
#   'state_of_license': 'UNKNOWN',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '37512A2',
#   'violation_description': 'SIDEWINGS/SIDEWINDOWS/NON/TRANSPARENT',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '18',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '403A1',
#   'violation_description': 'FLD YIELD PEDEST NYC',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '55',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1229C1B',
#   'violation_description': 'BACK SEAT PASS AGE 4-7 NO/IMPROPER RESTRAINT',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '29',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'QUEENS NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '22',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN NORTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225D',
#   'violation_description': 'OPER MV WHILE USING PORTABLE ELEC DEV',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '41',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'QUEENS SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225D',
#   'violation_description': 'OPER MV WHILE USING PORTABLE ELEC DEV',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '43',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'QUEENS SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225D',
#   'violation_description': 'OPER MV WHILE USING PORTABLE ELEC DEV',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '30',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'QUEENS SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225C2A',
#   'violation_description': 'OPERATING MV MOBILE PHONE',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '45',
#   'gender': 'M',
#   'state_of_license': 'NEW JERSEY',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '412M',
#   'violation_description': 'IMP USE BUS LANE NYC',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '36',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225D',
#   'violation_description': 'OPER MV WHILE USING PORTABLE ELEC DEV',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '31',
#   'gender': 'M',
#   'state_of_license': 'CALIFORNIA',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '48',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1180D12',
#   'violation_description': 'SPEED IN ZONE 11-30',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '33',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'RICHMOND TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1127AB',
#   'violation_description': 'DROVE WRONG DIRECTION BICYCLE',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '44',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'MANHATTAN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1180D12',
#   'violation_description': 'SPEED IN ZONE 11-30',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '72',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'RICHMOND TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '37512A2',
#   'violation_description': 'SIDEWINGS/SIDEWINDOWS/NON/TRANSPARENT',
#   'violation_year': '2019',
#   'violation_month': '1',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '18',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  ...]

# %%
len(data)
# Out:
# 500000

# %% [markdown]
# ### Filtering the data

# %%
parameters = {
    "violation_year":"2022",
    'violation_month': '2',
    'court': 'BROOKLYN SOUTH TVB'
}

url2 = "https://data.ny.gov/resource/q4hy-kbtf.json?$limit=500000"
headers = {
"Content-Type" : "application/json",
}


res = requests.get(url2,params=parameters)
print(res.status_code)
# Out:
# 200

# %%
data2 = res.text
data2 = json.loads(data2)
data2
# Out:
# [{'violation_charged_code': '1131',
#   'violation_description': 'DRIVING ON SHOULDER/LIMITED ACCESS HGWY',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '53',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1131',
#   'violation_description': 'DRIVING ON SHOULDER/LIMITED ACCESS HGWY',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '51',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '51',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '414A2',
#   'violation_description': 'NO CMV ON PKWAY NYC',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '51',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1131',
#   'violation_description': 'DRIVING ON SHOULDER/LIMITED ACCESS HGWY',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '62',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1180D12',
#   'violation_description': 'SPEED IN ZONE 11-30',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '25',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1180D12',
#   'violation_description': 'SPEED IN ZONE 11-30',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '22',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1180D12',
#   'violation_description': 'SPEED IN ZONE 11-30',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '35',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1180D12',
#   'violation_description': 'SPEED IN ZONE 11-30',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '24',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1180D12',
#   'violation_description': 'SPEED IN ZONE 11-30',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '20',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1180D12',
#   'violation_description': 'SPEED IN ZONE 11-30',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '20',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1180D12',
#   'violation_description': 'SPEED IN ZONE 11-30',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '23',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '5091JG',
#   'violation_description': 'UNLIC JR OP > 60 DAY',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '17',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1180D12',
#   'violation_description': 'SPEED IN ZONE 11-30',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '17',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '4011AG',
#   'violation_description': 'UNREG VEH > 60 DAYS',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '19',
#   'gender': 'M',
#   'state_of_license': 'UNKNOWN',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '3191U',
#   'violation_description': 'OPERATING W/O INSURANCE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '19',
#   'gender': 'M',
#   'state_of_license': 'UNKNOWN',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '5091G',
#   'violation_description': 'UNLICENSED GT 60DAYS',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '19',
#   'gender': 'M',
#   'state_of_license': 'UNKNOWN',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '29',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '303C',
#   'violation_description': 'FAIL DISPLAY/GIVE NOTICE/REINSPECTION',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '31',
#   'gender': 'M',
#   'state_of_license': 'UNKNOWN',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '31',
#   'gender': 'M',
#   'state_of_license': 'UNKNOWN',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '4025',
#   'violation_description': 'PERMITTING USE OF IMPROPER PLATES',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '39',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '5091G',
#   'violation_description': 'UNLICENSED GT 60DAYS',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '27',
#   'gender': 'M',
#   'state_of_license': 'UNKNOWN',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '5091G',
#   'violation_description': 'UNLICENSED GT 60DAYS',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'WEDNESDAY',
#   'age_at_violation': '34',
#   'gender': 'M',
#   'state_of_license': 'UNKNOWN',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225D',
#   'violation_description': 'OPER MV WHILE USING PORTABLE ELEC DEV',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '54',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '22',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225C2A',
#   'violation_description': 'OPERATING MV MOBILE PHONE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '36',
#   'gender': 'M',
#   'state_of_license': 'MARYLAND',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1229C3A',
#   'violation_description': 'NO LAP/SHOULDER HARNESS OR DJ VIO',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '32',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225D',
#   'violation_description': 'OPER MV WHILE USING PORTABLE ELEC DEV',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '32',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225D',
#   'violation_description': 'OPER MV WHILE USING PORTABLE ELEC DEV',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '41',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1229C3A',
#   'violation_description': 'NO LAP/SHOULDER HARNESS OR DJ VIO',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '18',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1229C3A',
#   'violation_description': 'NO LAP/SHOULDER HARNESS OR DJ VIO',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '24',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '405B1',
#   'violation_description': 'U-TRN BUSIN DIST NYC',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '37',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1172A',
#   'violation_description': 'FLD TO STOP AT STOP SIGN',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '22',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'SEAGATE NY HARBOR POLICE',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '37512A2',
#   'violation_description': 'SIDEWINGS/SIDEWINDOWS/NON/TRANSPARENT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '22',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1172A',
#   'violation_description': 'FLD TO STOP AT STOP SIGN',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'WEDNESDAY',
#   'age_at_violation': '26',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '4011AG',
#   'violation_description': 'UNREG VEH > 60 DAYS',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'WEDNESDAY',
#   'age_at_violation': '26',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '402C',
#   'violation_description': 'DANGEROUS DRIVING',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '21',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '30',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SATURDAY',
#   'age_at_violation': '47',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SATURDAY',
#   'age_at_violation': '45',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '61',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225C2A',
#   'violation_description': 'OPERATING MV MOBILE PHONE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '46',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '3752A1I',
#   'violation_description': 'INSUFF HEADLIGHTS',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'WEDNESDAY',
#   'age_at_violation': '43',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1127A',
#   'violation_description': 'DRIVING/WRONG DIRECTION ON ONE-WAY STREET',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '45',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '25',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '21',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '20',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1172A',
#   'violation_description': 'FLD TO STOP AT STOP SIGN',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '48',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225D',
#   'violation_description': 'OPER MV WHILE USING PORTABLE ELEC DEV',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '30',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225C2A',
#   'violation_description': 'OPERATING MV MOBILE PHONE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '36',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '406A22',
#   'violation_description': 'SPEED-PSTD 11-30 NYC',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '25',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '40',
#   'gender': 'F',
#   'state_of_license': 'UNKNOWN',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225C2A',
#   'violation_description': 'OPERATING MV MOBILE PHONE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '31',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225C2A',
#   'violation_description': 'OPERATING MV MOBILE PHONE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '38',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'WEDNESDAY',
#   'age_at_violation': '60',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225D',
#   'violation_description': 'OPER MV WHILE USING PORTABLE ELEC DEV',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '63',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '30',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '5091',
#   'violation_description': 'UNLICENSED OPERATOR',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '39',
#   'gender': 'F',
#   'state_of_license': 'CONNECTICUT',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225C2A',
#   'violation_description': 'OPERATING MV MOBILE PHONE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '39',
#   'gender': 'F',
#   'state_of_license': 'CONNECTICUT',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '403A1',
#   'violation_description': 'FLD YIELD PEDEST NYC',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '57',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225C2A',
#   'violation_description': 'OPERATING MV MOBILE PHONE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '31',
#   'gender': 'M',
#   'state_of_license': 'MARYLAND',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'WEDNESDAY',
#   'age_at_violation': '22',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '3752A1',
#   'violation_description': 'NO/INADEQUATE HEADLAMPS',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '41',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'WEDNESDAY',
#   'age_at_violation': '41',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1160A',
#   'violation_description': 'IMPROPER RIGHT TURN',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '33',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '3191P',
#   'violation_description': 'PERMITTING OPERATION W/O INSURANCE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SATURDAY',
#   'age_at_violation': '40',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '37512A2',
#   'violation_description': 'SIDEWINGS/SIDEWINDOWS/NON/TRANSPARENT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'WEDNESDAY',
#   'age_at_violation': '25',
#   'gender': 'F',
#   'state_of_license': 'UNKNOWN',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1172A',
#   'violation_description': 'FLD TO STOP AT STOP SIGN',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SATURDAY',
#   'age_at_violation': '40',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '37512A2',
#   'violation_description': 'SIDEWINGS/SIDEWINDOWS/NON/TRANSPARENT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '27',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '37512A2',
#   'violation_description': 'SIDEWINGS/SIDEWINDOWS/NON/TRANSPARENT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '32',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '37512A1',
#   'violation_description': 'FRONT WINDSHIELD NON/TRANSPARENT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '36',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225D',
#   'violation_description': 'OPER MV WHILE USING PORTABLE ELEC DEV',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '69',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225D',
#   'violation_description': 'OPER MV WHILE USING PORTABLE ELEC DEV',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '41',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1172A',
#   'violation_description': 'FLD TO STOP AT STOP SIGN',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SATURDAY',
#   'age_at_violation': '38',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225D',
#   'violation_description': 'OPER MV WHILE USING PORTABLE ELEC DEV',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '33',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225C2A',
#   'violation_description': 'OPERATING MV MOBILE PHONE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'WEDNESDAY',
#   'age_at_violation': '21',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225D',
#   'violation_description': 'OPER MV WHILE USING PORTABLE ELEC DEV',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '35',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '34',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1172A',
#   'violation_description': 'FLD TO STOP AT STOP SIGN',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '33',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1172A',
#   'violation_description': 'FLD TO STOP AT STOP SIGN',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'WEDNESDAY',
#   'age_at_violation': '48',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1172A',
#   'violation_description': 'FLD TO STOP AT STOP SIGN',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '66',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1172A',
#   'violation_description': 'FLD TO STOP AT STOP SIGN',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'WEDNESDAY',
#   'age_at_violation': '22',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '24',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '31',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1163DI',
#   'violation_description': 'IMPROPER SIGNAL',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '66',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '4031',
#   'violation_description': 'NO/IMPROPERLY AFFIXED REG STICKER',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '30',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '49',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '53',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '4011AG',
#   'violation_description': 'UNREG VEH > 60 DAYS',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '51',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '4024',
#   'violation_description': 'IMPROPER PLATES',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '25',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '42',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '37',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '37512A2',
#   'violation_description': 'SIDEWINGS/SIDEWINDOWS/NON/TRANSPARENT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '28',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1180D12',
#   'violation_description': 'SPEED IN ZONE 11-30',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '53',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D3',
#   'violation_description': 'FLD TO STOP ON A STEADY RED ARROW',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '62',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '28',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225C2A',
#   'violation_description': 'OPERATING MV MOBILE PHONE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '50',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1180D12',
#   'violation_description': 'SPEED IN ZONE 11-30',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '19',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D3',
#   'violation_description': 'FLD TO STOP ON A STEADY RED ARROW',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '57',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1180D12',
#   'violation_description': 'SPEED IN ZONE 11-30',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '32',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '403A1',
#   'violation_description': 'FLD YIELD PEDEST NYC',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '47',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1229C3A',
#   'violation_description': 'NO LAP/SHOULDER HARNESS OR DJ VIO',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '36',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1229C3A',
#   'violation_description': 'NO LAP/SHOULDER HARNESS OR DJ VIO',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '26',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225D',
#   'violation_description': 'OPER MV WHILE USING PORTABLE ELEC DEV',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '48',
#   'gender': 'M',
#   'state_of_license': 'UNKNOWN',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '5091G',
#   'violation_description': 'UNLICENSED GT 60DAYS',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '48',
#   'gender': 'M',
#   'state_of_license': 'UNKNOWN',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '403A1',
#   'violation_description': 'FLD YIELD PEDEST NYC',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '27',
#   'gender': 'M',
#   'state_of_license': 'NEW JERSEY',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '403A1',
#   'violation_description': 'FLD YIELD PEDEST NYC',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '52',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1163AS',
#   'violation_description': 'IMPROPER SIGNAL',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '52',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225D',
#   'violation_description': 'OPER MV WHILE USING PORTABLE ELEC DEV',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '42',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '42',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1229C3A',
#   'violation_description': 'NO LAP/SHOULDER HARNESS OR DJ VIO',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '70',
#   'gender': 'M',
#   'state_of_license': 'MASSACHUSETTS',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1163AT',
#   'violation_description': 'IMPROPER TURN',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '26',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225C2A',
#   'violation_description': 'OPERATING MV MOBILE PHONE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '38',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '58',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D3',
#   'violation_description': 'FLD TO STOP ON A STEADY RED ARROW',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '74',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1172A',
#   'violation_description': 'FLD TO STOP AT STOP SIGN',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '68',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '69',
#   'gender': 'M',
#   'state_of_license': 'PENNSYLVANIA',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '403A3II',
#   'violation_description': 'FLD YL PED RD LT-NYC',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '37',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1229C3A',
#   'violation_description': 'NO LAP/SHOULDER HARNESS OR DJ VIO',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '37',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '403A1',
#   'violation_description': 'FLD YIELD PEDEST NYC',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '63',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '37',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1229C3B',
#   'violation_description': 'NO SEAT BELT PASS-VEH OPER BY DJ',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '40',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '50',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '403A1',
#   'violation_description': 'FLD YIELD PEDEST NYC',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '59',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225D',
#   'violation_description': 'OPER MV WHILE USING PORTABLE ELEC DEV',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '67',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1163AS',
#   'violation_description': 'IMPROPER SIGNAL',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '59',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '67',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1229C3A',
#   'violation_description': 'NO LAP/SHOULDER HARNESS OR DJ VIO',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '27',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1229C3A',
#   'violation_description': 'NO LAP/SHOULDER HARNESS OR DJ VIO',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '25',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225D',
#   'violation_description': 'OPER MV WHILE USING PORTABLE ELEC DEV',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '33',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1180D12',
#   'violation_description': 'SPEED IN ZONE 11-30',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '30',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '412I',
#   'violation_description': 'HORN NO DANGER-NYC',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '50',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '403A1',
#   'violation_description': 'FLD YIELD PEDEST NYC',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '25',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '5091G',
#   'violation_description': 'UNLICENSED GT 60DAYS',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '25',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1229C3A',
#   'violation_description': 'NO LAP/SHOULDER HARNESS OR DJ VIO',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '28',
#   'gender': 'M',
#   'state_of_license': 'CALIFORNIA',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1229C3V',
#   'violation_description': 'NO BELT PASS TAXI16>',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '51',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225D',
#   'violation_description': 'OPER MV WHILE USING PORTABLE ELEC DEV',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '59',
#   'gender': 'M',
#   'state_of_license': 'NEW JERSEY',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '5091',
#   'violation_description': 'UNLICENSED OPERATOR',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'TUESDAY',
#   'age_at_violation': '28',
#   'gender': 'M',
#   'state_of_license': 'CALIFORNIA',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1180D12',
# ...
#   'age_at_violation': '25',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '26',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '59',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '40',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '46',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '35',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '403A1',
#   'violation_description': 'FLD YIELD PEDEST NYC',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '42',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '31',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '3191U',
#   'violation_description': 'OPERATING W/O INSURANCE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '27',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SATURDAY',
#   'age_at_violation': '35',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225C2A',
#   'violation_description': 'OPERATING MV MOBILE PHONE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '37',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '37512A2',
#   'violation_description': 'SIDEWINGS/SIDEWINDOWS/NON/TRANSPARENT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SATURDAY',
#   'age_at_violation': '22',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '3191U',
#   'violation_description': 'OPERATING W/O INSURANCE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SATURDAY',
#   'age_at_violation': '22',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '37540B',
#   'violation_description': 'INADEQUATE OR NO STOP LAMPS',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '33',
#   'gender': 'M',
#   'state_of_license': 'UNKNOWN',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '5091G',
#   'violation_description': 'UNLICENSED GT 60DAYS',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '33',
#   'gender': 'M',
#   'state_of_license': 'UNKNOWN',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1225D',
#   'violation_description': 'OPER MV WHILE USING PORTABLE ELEC DEV',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '39',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '68',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '42',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'FRIDAY',
#   'age_at_violation': '24',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1229C3',
#   'violation_description': 'NO SEAT BELT ADULT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '26',
#   'gender': 'F',
#   'state_of_license': 'UNKNOWN',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '4011A',
#   'violation_description': 'UNREGISTERED MOTOR VEHICLE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '28',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '5091G',
#   'violation_description': 'UNLICENSED GT 60DAYS',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'THURSDAY',
#   'age_at_violation': '26',
#   'gender': 'F',
#   'state_of_license': 'UNKNOWN',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '20',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SATURDAY',
#   'age_at_violation': '34',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '31',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '34',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1229C3A',
#   'violation_description': 'NO LAP/SHOULDER HARNESS OR DJ VIO',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '20',
#   'gender': 'M',
#   'state_of_license': 'FLORIDA',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '3191U',
#   'violation_description': 'OPERATING W/O INSURANCE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '20',
#   'gender': 'M',
#   'state_of_license': 'FLORIDA',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '4011AG',
#   'violation_description': 'UNREG VEH > 60 DAYS',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'WEDNESDAY',
#   'age_at_violation': '50',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '3191U',
#   'violation_description': 'OPERATING W/O INSURANCE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'WEDNESDAY',
#   'age_at_violation': '50',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SATURDAY',
#   'age_at_violation': '57',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1122A',
#   'violation_description': 'PASSED VEHICLE ON RIGHT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SATURDAY',
#   'age_at_violation': '57',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1163D',
#   'violation_description': 'IMPROPER SIGNAL',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '55',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '5091',
#   'violation_description': 'UNLICENSED OPERATOR',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '55',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '3752A1',
#   'violation_description': 'NO/INADEQUATE HEADLAMPS',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '37',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1127A',
#   'violation_description': 'DRIVING/WRONG DIRECTION ON ONE-WAY STREET',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '37',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '24',
#   'gender': 'F',
#   'state_of_license': 'UNKNOWN',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1151A',
#   'violation_description': 'FLD TO YLD RT-OF-WAY TO PEDESTRIAN ON SIDEWALK',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '30',
#   'gender': 'F',
#   'state_of_license': 'UNKNOWN',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '18',
#   'gender': 'M',
#   'state_of_license': 'UNKNOWN',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '40',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SATURDAY',
#   'age_at_violation': '28',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '28',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1163D',
#   'violation_description': 'IMPROPER SIGNAL',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'MONDAY',
#   'age_at_violation': '59',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SATURDAY',
#   'age_at_violation': '52',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SATURDAY',
#   'age_at_violation': '66',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1111D1N',
#   'violation_description': 'NYC REDLIGHT',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'SUNDAY',
#   'age_at_violation': '21',
#   'gender': 'F',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  {'violation_charged_code': '1110A',
#   'violation_description': 'DISOBEYED TRAFFIC DEVICE',
#   'violation_year': '2022',
#   'violation_month': '2',
#   'violation_dow': 'WEDNESDAY',
#   'age_at_violation': '76',
#   'gender': 'M',
#   'state_of_license': 'NEW YORK',
#   'police_agency': 'NYC POLICE DEPT',
#   'court': 'BROOKLYN SOUTH TVB',
#   'source': 'TVB'},
#  ...]

# %%
len(data2)
# Out:
# 8442

# %% [markdown]
# ### Creating dataframe

# %%
court_list = ["BRONX TVB","BROOKLYN NORTH TVB","BROOKLYN SOUTH TVB","MANHATTAN NORTH TVB","MANHATTAN SOUTH TVB",
              "QUEENS NORTH TVB","QUEENS SOUTH TVB","RICHMOND TVB"]

# %%
data_list = []
for month in range(1,13):
    for court in court_list:
        parameters = {"violation_year":"2022",'violation_month': str(month),'court': court}
        url2 = "https://data.ny.gov/resource/q4hy-kbtf.json?$limit=500000"
        res = requests.get(url2,params=parameters)
        number = len(json.loads(res.text))
        
        data_list.append([court, str(month), "2022", str(number)])
        
        
data = pd.DataFrame(data_list,columns = ["court","violation_month","violation_year","no_of_violations"])
data
# Out:
#                   court violation_month violation_year no_of_violations
# 0             BRONX TVB               1           2022             6867
# 1    BROOKLYN NORTH TVB               1           2022             4021
# 2    BROOKLYN SOUTH TVB               1           2022             7359
# 3   MANHATTAN NORTH TVB               1           2022             4704
# 4   MANHATTAN SOUTH TVB               1           2022             5379
# ..                  ...             ...            ...              ...
# 91  MANHATTAN NORTH TVB              12           2022             6139
# 92  MANHATTAN SOUTH TVB              12           2022             5234
# 93     QUEENS NORTH TVB              12           2022             5884
# 94     QUEENS SOUTH TVB              12           2022             5496
# 95         RICHMOND TVB              12           2022             4288
#
# [96 rows x 4 columns]

# %%
def split_court(col):
    return col.split(" ")[0]

# %%
data["court"] = data["court"].apply(split_court)
dataFrame = data.groupby(["court","violation_month","violation_year"]).sum().reset_index()
dataFrame
# Out:
#         court violation_month violation_year no_of_violations
# 0       BRONX               1           2022             6867
# 1       BRONX              10           2022             8760
# 2       BRONX              11           2022             8621
# 3       BRONX              12           2022             7898
# 4       BRONX               2           2022             6684
# 5       BRONX               3           2022             8328
# 6       BRONX               4           2022             7519
# 7       BRONX               5           2022             7742
# 8       BRONX               6           2022             8205
# 9       BRONX               7           2022             8306
# 10      BRONX               8           2022             9381
# 11      BRONX               9           2022             9343
# 12   BROOKLYN               1           2022         40217359
# 13   BROOKLYN              10           2022         74859614
# 14   BROOKLYN              11           2022         72549105
# 15   BROOKLYN              12           2022         55308174
# 16   BROOKLYN               2           2022         54068442
# 17   BROOKLYN               3           2022         63859218
# 18   BROOKLYN               4           2022         59588059
# 19   BROOKLYN               5           2022         72488572
# 20   BROOKLYN               6           2022         61698269
# 21   BROOKLYN               7           2022         62298336
# 22   BROOKLYN               8           2022         63657862
# 23   BROOKLYN               9           2022         71917386
# 24  MANHATTAN               1           2022         47045379
# 25  MANHATTAN              10           2022         63068107
# 26  MANHATTAN              11           2022         66785898
# 27  MANHATTAN              12           2022         61395234
# 28  MANHATTAN               2           2022         50466782
# 29  MANHATTAN               3           2022         72457859
# 30  MANHATTAN               4           2022         59037840
# 31  MANHATTAN               5           2022         66717850
# 32  MANHATTAN               6           2022         63546871
# 33  MANHATTAN               7           2022         54986683
# 34  MANHATTAN               8           2022         59467097
# 35  MANHATTAN               9           2022         63096573
# 36     QUEENS               1           2022         50304932
# 37     QUEENS              10           2022         65776369
# 38     QUEENS              11           2022         58055965
# 39     QUEENS              12           2022         58845496
# 40     QUEENS               2           2022         55276328
# 41     QUEENS               3           2022         62237784
# 42     QUEENS               4           2022         59576031
# 43     QUEENS               5           2022         60086349
# 44     QUEENS               6           2022         68976268
# 45     QUEENS               7           2022         64675728
# 46     QUEENS               8           2022         55985666
# 47     QUEENS               9           2022         56375893
# 48   RICHMOND               1           2022             4454
# 49   RICHMOND              10           2022             4733
# 50   RICHMOND              11           2022             4544
# 51   RICHMOND              12           2022             4288
# 52   RICHMOND               2           2022             4899
# 53   RICHMOND               3           2022             5394
# 54   RICHMOND               4           2022             5448
# 55   RICHMOND               5           2022             5690
# 56   RICHMOND               6           2022             4549
# 57   RICHMOND               7           2022             4277
# 58   RICHMOND               8           2022             4236
# 59   RICHMOND               9           2022             4325

# %% [markdown]
# ### Storing in MySQL

# %%
# Establish connection to AWS RDS database
host = 'database-3.csuqjb4hx3vr.us-east-1.rds.amazonaws.com'
user = 'admin'
password = 'jackisback'
db_name = 'CAR_CRASH_DATA'

# %%
conn = pymysql.connect(host=host, user=user, password=password, db=db_name)

try:
   # Create SQLAlchemy engine to connect to MySQL Database
    engine = create_engine("mysql+pymysql://{user}:{pw}@{host}/{db}"
				.format(host=host, db=db_name, user=user, pw=password))

    # Convert dataframe to sql table                                   
    dataFrame.to_sql('traffic_violations_data', engine, index=False)

except ValueError as vx:
    print(vx)
except Exception as ex:
    print(ex)
else:
    print("Table is created successfully.")
finally:
    conn.close()
# Out:
# Table is created successfully.
